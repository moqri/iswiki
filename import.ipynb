# %%
import pandas as pd

# %%
df=pd.read_csv("articles_2010.csv")
df
# Out:
#      Unnamed: 0 ���PT                                                 AU  BA  \
# 0             0     J                     Vance, A; Lowry, PB; Eggett, D NaN
# 1             1     J                          Willison, R; Warkentin, M NaN
# 2             2     J                   Venkatesh, V; Brown, SA; Bala, H NaN
# 3             3     J    Adomavicius, G; Curley, SP; Gupta, A; Sanyal, P NaN
# 4             4     J               Tan, CW; Benbasat, I; Cenfetelli, RT NaN
# 5             5     J                        Liu, D; Li, X; Santhanam, R NaN
# 6             6     J        Chen, R; Sharman, R; Rao, HR; Upadhyaya, SJ NaN
# 7             7     J                     Wang, ETG; Tai, JCF; Grover, V NaN
# 8             8     J                                              Su, N NaN
# 9             9     J              Barrett, M; Heracleous, L; Walsham, G NaN
# 10           10     J                          Polites, GL; Karahanna, E NaN
# ...

# %%
for i in range(1):
    row=next(df.iterrows())[1]
    title=row['TI']
    authors=row['AF']

# %%
authorsl=authors.split(';')
for autho in authorsl:
    print author
# Out:
#   File "<ipython-input-63-6cd3cae3856f>", line 2
#     for autho in authorsl:
#                           ^
# IndentationError: expected an indented block
